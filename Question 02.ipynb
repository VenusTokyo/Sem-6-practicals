# %% [markdown]
# ### Q2) Perform elementary logical operations in Python (like OR, AND, Checking for Equality, NOT, XOR).

# %%
def main():
    ans="Y"
    while(ans=="y" or ans=="Y"):
        print("\n\t-_-_-_-_-_-_-_-_-_-MENU-_-_-_-_-_-_-_-_-_-\n")
        print("1)OR\n2)AND\n3)Check for Equality\n4)NOT\n5)XOR")
        ch=int(input("\n\tEnter an option: "))
        x=int(input("\nEnter a number(x): "))
        if(ch==1):
            print(" x < 4 OR x > 10: ",(x<4 or x>10))
        elif(ch==2):
            print(" x > 3 AND x < 10: ",(x>3 and x<10))
        elif(ch==3):
            print("x==5: ",x==5)
        elif(ch==4):
            print("NOT x: ",not x)
        elif(ch==5):
            print("2 XOR x: ",2^x)
        else:
            print("Enter valid option")
        
        ans=input("Enter do you want to try again? {Y/N}: ")
        print("\n-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*\n")
        
main()
# Out:
# 	-_-_-_-_-_-_-_-_-_-MENU-_-_-_-_-_-_-_-_-_-
#
# 1)OR
# 2)AND
# 3)Check for Equality
# 4)NOT
# 5)XOR
#
# 	Enter an option: 1
#
# Enter a number(x): 4
#  x < 4 OR x > 10:  False
# Enter do you want to try again? {Y/N}: Y
#
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#
#
# 	-_-_-_-_-_-_-_-_-_-MENU-_-_-_-_-_-_-_-_-_-
#
# 1)OR
# 2)AND
# 3)Check for Equality
# 4)NOT
# 5)XOR
#
# 	Enter an option: 2
#
# Enter a number(x): 6
#  x > 3 AND x < 10:  True
# Enter do you want to try again? {Y/N}: Y
#
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#
#
# 	-_-_-_-_-_-_-_-_-_-MENU-_-_-_-_-_-_-_-_-_-
#
# 1)OR
# 2)AND
# 3)Check for Equality
# 4)NOT
# 5)XOR
#
# 	Enter an option: 3
#
# Enter a number(x): 8
# x==5:  False
# Enter do you want to try again? {Y/N}: Y
#
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#
#
# 	-_-_-_-_-_-_-_-_-_-MENU-_-_-_-_-_-_-_-_-_-
#
# 1)OR
# 2)AND
# ...
